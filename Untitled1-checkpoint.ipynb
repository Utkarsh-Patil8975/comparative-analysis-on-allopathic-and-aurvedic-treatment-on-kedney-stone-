# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\USER\Desktop\ind.csv")
data
# Out:
#     id  age  yrmig    wt    ht  chin  fore  calf  pulse  sysbp  diabp
# 0    1   21      1  71.0  1629   8.0   7.0  12.7     88    170     76
# 1    2   22      6  56.5  1569   3.3   5.0   8.0     64    120     60
# 2    3   24      5  56.0  1561   3.3   1.3   4.3     68    125     75
# 3    4   24      1  61.0  1619   3.7   3.0   4.3     52    148    120
# 4    5   25      1  65.0  1566   9.0  12.7  20.7     72    140     78
# 5    6   27     19  62.0  1639   3.0   3.3   5.7     72    106     72
# 6    7   28      5  53.0  1494   7.3   4.7   8.0     64    120     76
# 7    8   28     25  53.0  1568   3.7   4.3   0.0     80    108     62
# 8    9   31      6  65.0  1540  10.3   9.0  10.0     76    124     70
# 9   10   32     13  57.0  1530   5.7   4.0   6.0     60    134     64
# 10  11   33     13  66.5  1622   6.0   5.7   8.3     68    116     76
# 11  12   33     10  59.1  1486   6.7   5.3  10.3     73    114     74
# ...

# %%
l=list("1234")
l[0]=l[1]=5
print(l)
# Out:
# [5, 5, '3', '4']

# %%
print(data.shape)
# Out:
# (39, 11)

# %%
data.columns
# Out:
# Index(['id', 'age', 'yrmig', 'wt', 'ht', 'chin', 'fore', 'calf', 'pulse',
#        'sysbp', 'diabp'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id         int64
# age        int64
# yrmig      int64
# wt       float64
# ht         int64
# chin     float64
# fore     float64
# calf     float64
# pulse      int64
# sysbp      int64
# diabp      int64
# dtype: object

# %%
data.info
# Out:
# <bound method DataFrame.info of     id  age  yrmig    wt    ht  chin  fore  calf  pulse  sysbp  diabp
# 0    1   21      1  71.0  1629   8.0   7.0  12.7     88    170     76
# 1    2   22      6  56.5  1569   3.3   5.0   8.0     64    120     60
# 2    3   24      5  56.0  1561   3.3   1.3   4.3     68    125     75
# 3    4   24      1  61.0  1619   3.7   3.0   4.3     52    148    120
# 4    5   25      1  65.0  1566   9.0  12.7  20.7     72    140     78
# 5    6   27     19  62.0  1639   3.0   3.3   5.7     72    106     72
# 6    7   28      5  53.0  1494   7.3   4.7   8.0     64    120     76
# 7    8   28     25  53.0  1568   3.7   4.3   0.0     80    108     62
# 8    9   31      6  65.0  1540  10.3   9.0  10.0     76    124     70
# 9   10   32     13  57.0  1530   5.7   4.0   6.0     60    134     64
# 10  11   33     13  66.5  1622   6.0   5.7   8.3     68    116     76
# 11  12   33     10  59.1  1486   6.7   5.3  10.3     73    114     74
# ...

# %%
data.loc()

# %%
data.tail(n=1)
# Out:
#     id  age  yrmig    wt    ht  chin  fore  calf  pulse  sysbp  diabp
# 38  39   54     40  87.0  1542  11.3  11.7  11.3     92    152     88

# %%
data.head(n=1)
# Out:
#    id  age  yrmig    wt    ht  chin  fore  calf  pulse  sysbp  diabp
# 0   1   21      1  71.0  1629   8.0   7.0  12.7     88    170     76

# %%
data.iloc[1]
# Out:
# id          2.0
# age        22.0
# yrmig       6.0
# wt         56.5
# ht       1569.0
# chin        3.3
# fore        5.0
# calf        8.0
# pulse      64.0
# sysbp     120.0
# diabp      60.0
# Name: 1, dtype: float64
