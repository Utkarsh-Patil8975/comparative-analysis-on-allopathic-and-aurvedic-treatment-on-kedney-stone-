# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.stats as stats
from scipy.stats import spearmanr

from scipy.stats import chi2_contingency

# %%
data=pd.read_csv(r"C:\Users\USER\Desktop\Activity 2023-24\Python project\ONLINE EDUCATION SYSTEM REVIEW (Pyhton project).csv")
data.head()
# Out:
#   Gender Home Location Level of Education  Age(Years)  Number of Subjects  \
# 0   Male         Urban     Under Graduate          18                  11
# 1   Male         Urban     Under Graduate          19                   7
# 2   Male         Rural     Under Graduate          18                   5
# 3   Male         Urban     Under Graduate          18                   5
# 4   Male         Rural     Under Graduate          18                   5
#
#   Device type used to attend classes Economic status  Family size  \
# 0                             Laptop    Middle Class            4
# 1                             Laptop    Middle Class            4
# 2                             Laptop    Middle Class            5
# 3                             Laptop    Middle Class            4
# 4                             Laptop    Middle Class            4
#
#    Internet facility in your locality Are you involved in any sports?  ...  \
# ...

# %%
data.columns
# Out:
# Index(['Gender', 'Home Location', 'Level of Education', 'Age(Years)',
#        'Number of Subjects', 'Device type used to attend classes',
#        'Economic status', 'Family size', 'Internet facility in your locality',
#        'Are you involved in any sports?', 'Do elderly people monitor you?',
#        'Study time (Hours)', 'Sleep time (Hours)',
#        'Time spent on social media (Hours)', 'Interested in Gaming?',
#        'Have separate room for studying?', 'Engaged in group studies?',
#        'Averag marks scored before pandemic in traditional classroom',
#        'Your interaction in online mode',
#        'Clearing doubts with faculties in online mode', 'Interested in?',
#        'Performance in online',
#        'Your level of satisfaction in Online Education'],
#       dtype='object')

# %% [markdown]
# # pearson's correlation

# %%
x = ['Averag marks scored before pandemic in traditional classroom']
y = ['Study time (Hours)' ]
corr_coeff, p_value = spearmanr(x, y)

print("Spearman's rank correlation coefficient:", corr_coeff)
print("P-value:", p_value)
# Out:
# Spearman's rank correlation coefficient: nan
# P-value: nan

# %% [markdown]
# # kruskal walis

# %%
groups = [data[data['Level of Education'] == group][ 'Study time (Hours)'] for group in data['Level of Education'].unique()]

# Performing Kruskal-Wallis test
h_statistic, p_value = stats.kruskal(*groups)

# Printing the results
print("H-Statistic:", h_statistic)
print("P-Value:", p_value)

# Checking significance
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis: There is significant evidence that at least one group median is different.")
else:
    print("Fail to reject null hypothesis: There is no significant evidence that the group medians are different.")
# Out:
# H-Statistic: 5.675545544686408
# P-Value: 0.05855593824276246
# Fail to reject null hypothesis: There is no significant evidence that the group medians are different.

# %% [markdown]
# # chi Square

# %%
contingency_table=pd.crosstab(data['Level of Education'],data['Device type used to attend classes'])
contingency_table
# Out:
# Device type used to attend classes  Desktop  Laptop  Mobile
# Level of Education
# Post Graduate                             6      70      53
# School                                    6      63      18
# Under Graduate                           16     538     263

# %%
chi2_stat,p_value,dof,expected= chi2_contingency(contingency_table)
print(f"Chi2 Stat: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies table:")
print(expected)
# Out:
# Chi2 Stat: 18.946962621097978
# P-value: 0.0008050269220711985
# Degrees of freedom: 4
# Expected frequencies table:
# [[  3.49661181  83.79380445  41.70958374]
#  [  2.35818006  56.51210068  28.12971926]
#  [ 22.14520813 530.69409487 264.160697  ]]

# %%
contingency_table=pd.crosstab(data['Gender'],data['Device type used to attend classes'])
contingency_table
# Out:
# Device type used to attend classes  Desktop  Laptop  Mobile
# Gender
# Female                                    7     266     146
# Male                                     21     405     188

# %%
chi2_stat,p_value,dof,expected= chi2_contingency(contingency_table)
print(f"Chi2 Stat: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies table:")
print(expected)
# Out:
# Chi2 Stat: 4.423127749200422
# P-value: 0.10952922453541321
# Degrees of freedom: 2
# Expected frequencies table:
# [[ 11.357212   272.16747338 135.47531462]
#  [ 16.642788   398.83252662 198.52468538]]

# %%
contingency_table=pd.crosstab(data['Gender'],data['Your level of satisfaction in Online Education'])
contingency_table
# Out:
# Your level of satisfaction in Online Education  Neutral  Satisfied  \
# Gender
# Female                                              234        114
# Male                                                307        137
#
# Your level of satisfaction in Online Education  Unsatisfied
# Gender
# Female                                                   71
# Male                                                    170

# %%
chi2_stat,p_value,dof,expected= chi2_contingency(contingency_table)
print(f"Chi2 Stat: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies table:")
print(expected)
# Out:
# Chi2 Stat: 16.400039809875135
# P-value: 0.0002746481030643887
# Degrees of freedom: 2
# Expected frequencies table:
# [[219.4375605  101.80929332  97.75314618]
#  [321.5624395  149.19070668 143.24685382]]

# %%
contingency_table=pd.crosstab(data['Level of Education'],data['Your level of satisfaction in Online Education'])
contingency_table
# Out:
# Your level of satisfaction in Online Education  Neutral  Satisfied  \
# Level of Education
# Post Graduate                                        70         37
# School                                               41         24
# Under Graduate                                      430        190
#
# Your level of satisfaction in Online Education  Unsatisfied
# Level of Education
# Post Graduate                                            22
# School                                                   22
# Under Graduate                                          197

# %%
chi2_stat,p_value,dof,expected= chi2_contingency(contingency_table)
print(f"Chi2 Stat: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies table:")
print(expected)
# Out:
# Chi2 Stat: 4.863606411628879
# P-value: 0.30158078146975
# Degrees of freedom: 4
# Expected frequencies table:
# [[ 67.55953533  31.3446273   30.09583737]
#  [ 45.56340755  21.13939981  20.29719264]
#  [427.87705712 198.51597289 190.60696999]]

# %%
contingency_table=pd.crosstab(data['Economic status'],data['Device type used to attend classes'])
contingency_table
# Out:
# Device type used to attend classes  Desktop  Laptop  Mobile
# Economic status
# Middle Class                             27     626     301
# Poor                                      1      17      31
# Rich                                      0      28       2

# %%
chi2_stat,p_value,dof,expected= chi2_contingency(contingency_table)
print(f"Chi2 Stat: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies table:")
print(expected)
# Out:
# Chi2 Stat: 32.42929577702472
# P-value: 1.5630254158891592e-06
# Degrees of freedom: 4
# Expected frequencies table:
# [[ 25.85866409 619.68441433 308.45692159]
#  [  1.32817038  31.8286544   15.84317522]
#  [  0.81316554  19.48693127   9.69990319]]

# %%
fx=sns.boxplot(x= 'Level of Education',y= 'Study time (Hours)' ,data=data)
plt.show()

# %%
sns.boxplot(data=data, y='Your interaction in online mode', orient='v')

# Set the title and axis labels
plt.title('Boxplot of interaction in online mode')
plt.xlabel('Interaction')
plt.ylabel('Level')

# Show the plot
plt.show()

# %%
sns.boxplot(data=data, y='Clearing doubts with faculties in online mode', orient='v')

# Set the title and axis labels
plt.title('Boxplot of Clearing doubts with faculties in online mode')
plt.xlabel('The performance of solving doubts online')
plt.ylabel('Score')

# Show the plot
plt.show()

# %%
sns.scatterplot(data=data, x='Study time (Hours)',y='Averag marks scored before pandemic in traditional classroom')
# Out:
# <Axes: xlabel='Study time (Hours)', ylabel='Averag marks scored before pandemic in traditional classroom'>

# %%
# Selecting the numerical columns for the scatter plot
x = data['Averag marks scored before pandemic in traditional classroom']
y = data['Study time (Hours)']

# Creating the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', alpha=0.5)
plt.title('Average marks scored before pandemic in traditional classroom vs Study time (Hours)')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')

plt.show()

# %%
count_result = data['Your level of satisfaction in Online Education'].value_counts()
count_result
# Out:
# Your level of satisfaction in Online Education
# Neutral        541
# Satisfied      251
# Unsatisfied    241
# Name: count, dtype: int64

# %%
lab=["Neutral","Satisfied ","Unsatisfied "]
plt.pie(count_result,labels=lab,autopct="%1.1f%%")
plt.legend(loc="upper right")
plt.title('level of satisfaction in Online Education')
plt.show()

# %%
import matplotlib.pyplot as plt

for col in data.columns:
    plt.figure(figsize=(5,5))
    data[col].value_counts().plot.pie(autopct='%1.1f%%')
    plt.title(col + " Distribution")
    plt.show()

# %%
for col in data.columns:
    plt.figure(figsize=(5,5))
    sns.countplot(x=col, data=data)
    plt.title(col + " Distribution")
    plt.show()
