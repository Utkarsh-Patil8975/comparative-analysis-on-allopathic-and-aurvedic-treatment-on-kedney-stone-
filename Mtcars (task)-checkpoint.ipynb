# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\USER\Downloads\MtCars dataset\a412dfbd88b3db70b74b-5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1\mtcars.csv")
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
sns.scatterplot(data=data, x='mpg',y='disp')
# Out:
# <Axes: xlabel='mpg', ylabel='disp'>

# %%
sns.scatterplot(data=data, x='hp',y='drat')
# Out:
# <Axes: xlabel='hp', ylabel='drat'>

# %%
sns.scatterplot(data=data, x='wt',y='qsec')
# Out:
# <Axes: xlabel='wt', ylabel='qsec'>

# %%
sns.scatterplot(data=data, x='mpg',y='hp')
# Out:
# <Axes: xlabel='mpg', ylabel='hp'>

# %%
sns.scatterplot(data=data, x='mpg',y='drat')
# Out:
# <Axes: xlabel='mpg', ylabel='drat'>

# %%
sns.scatterplot(data=data, x='mpg',y='wt')
# Out:
# <Axes: xlabel='mpg', ylabel='wt'>

# %%
sns.scatterplot(data=data, x='mpg',y='wt')
# Out:
# <Axes: xlabel='mpg', ylabel='wt'>

# %%
sns.scatterplot(data=data, x='mpg',y='qsec')
# Out:
# <Axes: xlabel='mpg', ylabel='qsec'>

# %%
sns.scatterplot(data=data, x='disp',y='hp')
# Out:
# <Axes: xlabel='disp', ylabel='hp'>

# %%
sns.scatterplot(data=data, x='disp',y='drat')
# Out:
# <Axes: xlabel='disp', ylabel='drat'>

# %%
sns.scatterplot(data=data, x='disp',y='wt')
# Out:
# <Axes: xlabel='disp', ylabel='wt'>

# %%
sns.scatterplot(data=data, x='disp',y='qsec')
# Out:
# <Axes: xlabel='disp', ylabel='qsec'>

# %%
sns.scatterplot(data=data, x='hp',y='mpg')
# Out:
# <Axes: xlabel='hp', ylabel='mpg'>

# %%
sns.scatterplot(data=data, x='hp',y='qsec')
# Out:
# <Axes: xlabel='hp', ylabel='qsec'>

# %%
sns.scatterplot(data=data, x='hp',y='wt')
# Out:
# <Axes: xlabel='hp', ylabel='wt'>

# %%
sns.scatterplot(data=data, x='drat',y='qsec')
# Out:
# <Axes: xlabel='drat', ylabel='qsec'>

# %%
fx=sns.boxplot(x='vs',y= 'mpg' ,data=data)
plt.show()

# %%
fx=sns.boxplot(x='cyl',y= 'disp' ,data=data)
plt.show()

# %%
fx=sns.boxplot(x='am',y= 'mpg' ,data=data)
plt.show()

# %%
fx=sns.boxplot(x='am',y=  'hp' ,data=data)
plt.show()

# %%
fx=sns.boxplot(x='gear',y=  'wt' ,data=data)
plt.show()

# %%
fx=sns.boxplot(x='carb',y=  'qsec' ,data=data)
plt.show()

# %%
data=data.drop(['model'],axis=1)

# %%
list=[ 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
       'gear', 'carb']
for i in list:
 fx=data.boxplot(list)
plt.show()
print(i)
# Out:
# carb

# %%
for col in data.columns:
    fx=data.boxplot(col)
    plt.show()
print(col)
# Out:
# carb
