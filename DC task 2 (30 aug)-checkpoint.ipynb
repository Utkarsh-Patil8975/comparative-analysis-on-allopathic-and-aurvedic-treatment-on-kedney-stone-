# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r"C:\Users\USER\Desktop\Activity  2024-25\Data Mining\DT_Data_con.xlsx")
data.head()
# Out:
#            y         x1
# 0  28.664822   3.122949
# 1  23.796160   4.602661
# 2  23.561803   5.557394
# 3  33.627269   9.680557
# 4  20.344442  11.463525

# %%
data.columns
# Out:
# Index(['y', 'x1'], dtype='object')

# %%
X=data[['x1']]
y=data[['y']]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor=DecisionTreeRegressor()

# %%
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
predicted_value=regressor.predict(X)
print(predicted_value)
# Out:
# [28.6648217  23.79615959 23.56180258 33.62726933 20.34444193 21.09543142
#  10.40409099 24.03537614 13.94866312 16.00906014 19.23269957  8.81114881
#   5.9740466   8.64332833  7.48530389  7.54377926 17.07821055 -0.61398933
#  14.17332583]

# %%
print(y)
# Out:
#             y
# 0   28.664822
# 1   23.796160
# 2   23.561803
# 3   33.627269
# 4   20.344442
# 5   21.095431
# 6   10.404091
# 7   24.035376
# 8   13.948663
# 9   16.009060
# 10  19.232700
# 11   8.811149
# 12   5.974047
# 13   8.643328
# 14   7.485304
# 15   7.543779
# 16  17.078211
# 17  -0.613989
# 18  14.173326

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error

# %%
mse = metrics.mean_squared_error(y, predicted_value)
print(mse)
# Out:
# 0.0

# %%
from sklearn import tree

# %%
tree.plot_tree(regressor, feature_names=['x1'])
# Out:
# [Text(0.5875, 0.9444444444444444, 'x1 <= 16.723\nsquared_error = 72.385\nsamples = 19\nvalue = 15.99'),
#  Text(0.275, 0.8333333333333334, 'x1 <= 10.572\nsquared_error = 39.182\nsamples = 11\nvalue = 21.338'),
#  Text(0.15, 0.7222222222222222, 'x1 <= 7.619\nsquared_error = 17.024\nsamples = 4\nvalue = 27.413'),
#  Text(0.1, 0.6111111111111112, 'x1 <= 3.863\nsquared_error = 5.533\nsamples = 3\nvalue = 25.341'),
#  Text(0.05, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 28.665'),
#  Text(0.15, 0.5, 'x1 <= 5.08\nsquared_error = 0.014\nsamples = 2\nvalue = 23.679'),
#  Text(0.1, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 23.796'),
#  Text(0.2, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 23.562'),
#  Text(0.2, 0.6111111111111112, 'squared_error = 0.0\nsamples = 1\nvalue = 33.627'),
#  Text(0.4, 0.7222222222222222, 'x1 <= 12.385\nsquared_error = 18.711\nsamples = 7\nvalue = 17.867'),
# ...

# %% [markdown]
# # Task - 3

# %%
data_1=pd.read_excel(r"C:\Users\USER\Desktop\Activity  2024-25\Data Mining\Decision  tree wheter data set.xlsx")
data_1
# Out:
#     Outlook  Temp  Humidity  Windy  HoursePlayed
# 0         1     1         1      1            26
# 1         1     1         1      2            30
# 2         2     1         1      1            48
# 3         3     2         1      1            46
# 4         3     3         2      1            52
# 5         3     3         2      2            23
# 6         2     3         2      2            43
# 7         1     2         1      1            36
# 8         1     3         2      1            38
# 9         3     2         2      1            48
# 10        1     2         2      1            48
# 11        2     2         1      2            52
# 12        2     1         2      1            44
# 13        3     2         1      2            30

# %%
data_1.columns
# Out:
# Index(['Outlook', 'Temp', 'Humidity', 'Windy', 'HoursePlayed'], dtype='object')

# %%
X = data_1[['Outlook', 'Temp', 'Humidity', 'Windy']]
y = data_1['HoursePlayed']

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor()

# %%
predicted_value=regressor.predict(X)
print(predicted_value)
# Out:
# [26. 30. 48. 46. 52. 23. 43. 36. 38. 48. 48. 52. 44. 30.]

# %%
print(y)
# Out:
# 0     26
# 1     30
# 2     48
# 3     46
# 4     52
# 5     23
# 6     43
# 7     36
# 8     38
# 9     48
# 10    48
# 11    52
# 12    44
# 13    30
# Name: HoursePlayed, dtype: int64

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error

# %%
mse = metrics.mean_squared_error(y, predicted_value)
print(mse)
# Out:
# 0.0

# %%
from sklearn import tree

# %%
tree.plot_tree(regressor, feature_names=['Outlook', 'Temp', 'Humidity', 'Windy'])
# Out:
# [Text(0.43478260869565216, 0.9166666666666666, 'Outlook <= 1.5\nsquared_error = 88.918\nsamples = 14\nvalue = 40.286'),
#  Text(0.17391304347826086, 0.75, 'Temp <= 1.5\nsquared_error = 56.64\nsamples = 5\nvalue = 35.6'),
#  Text(0.08695652173913043, 0.5833333333333334, 'Windy <= 1.5\nsquared_error = 4.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.043478260869565216, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 26.0'),
#  Text(0.13043478260869565, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.2608695652173913, 0.5833333333333334, 'Humidity <= 1.5\nsquared_error = 27.556\nsamples = 3\nvalue = 40.667'),
#  Text(0.21739130434782608, 0.4166666666666667, 'squared_error = 0.0\nsamples = 1\nvalue = 36.0'),
#  Text(0.30434782608695654, 0.4166666666666667, 'Temp <= 2.5\nsquared_error = 25.0\nsamples = 2\nvalue = 43.0'),
#  Text(0.2608695652173913, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = 48.0'),
# ...

# %% [markdown]
# # Task 3  Sir code

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
#df= pd.read_csv(r"C:\Users\USER\Desktop\Activity  2024-25\Data Mining\DT_Data.csv") 
#df.head()

# %%
cleanup_nums = {"Outlook":{"Rainy": 1, "Overcast": 2,"Sunny":3},"Temp":{"Hot": 1, "Mild": 2, "Cool": 3},"Humidity":{"High":1,"Normal":2}}

# %%
cleanup_nums = {"Outlook":{"Rainy": 1, "Overcast": 2,"Sunny":3},"Temp":{"Hot": 1, "Mild": 2, "Cool": 3}, "Humidity":{"High":1,"Normal":2},"Windy":{"F":1,"T":2}}

# %%
df = data.replace(cleanup_nums)
#data1.to_csv("Data_3_var.csv")
df.head()
# Out:
#            y         x1
# 0  28.664822   3.122949
# 1  23.796160   4.602661
# 2  23.561803   5.557394
# 3  33.627269   9.680557
# 4  20.344442  11.463525

# %%
regressor = DecisionTreeRegressor(random_state = 0,max_depth=2)
x = df.drop(["y"],axis=1)
y = df["y"]
#Fit the regressor object to the dataset.
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=0)

# %%
y_pred = regressor.predict(x)
y_pred
# Out:
# array([27.4125133 , 27.4125133 , 27.4125133 , 27.4125133 , 17.86710905,
#        17.86710905, 17.86710905, 17.86710905, 17.86710905, 17.86710905,
#        17.86710905,  7.84597545,  7.84597545,  7.84597545,  7.84597545,
#         7.84597545,  7.84597545,  7.84597545, 14.17332583])

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(x, y)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.7373892504536766

# %%
x.columns
# Out:
# Index(['x1'], dtype='object')

# %%
from sklearn import tree

# %%
tree.plot_tree(regressor,feature_names=['Outlook', 'Temp', 'Humidity', 'Windy'])
# Out:
# [Text(0.5, 0.8333333333333334, 'Outlook <= 16.723\nsquared_error = 72.385\nsamples = 19\nvalue = 15.99'),
#  Text(0.25, 0.5, 'Outlook <= 10.572\nsquared_error = 39.182\nsamples = 11\nvalue = 21.338'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 17.024\nsamples = 4\nvalue = 27.413'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 18.711\nsamples = 7\nvalue = 17.867'),
#  Text(0.75, 0.5, 'Outlook <= 41.601\nsquared_error = 24.641\nsamples = 8\nvalue = 8.637'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 23.157\nsamples = 7\nvalue = 7.846'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 14.173')]

# %% [markdown]
# # Task 4 (Real Combine)

# %%
##Import Library 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_2=pd.read_excel(r"C:\Users\USER\Desktop\Activity  2024-25\Data Mining\Real_Combine.xlsx")
data_2.head()
# Out:
#       T    TM   Tm     SLP   H   VV    V    VM           Y
# 0   7.4   9.8  4.8  1017.6  93  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61  1.3  8.7  22.2  200.645833

# %%
data_2.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM', 'Y'], dtype='object')

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       1057 non-null   float64
#  1   TM      1057 non-null   float64
#  2   Tm      1057 non-null   float64
#  3   SLP     1057 non-null   float64
#  4   H       1057 non-null   int64
#  5   VV      1057 non-null   float64
#  6   V       1057 non-null   float64
#  7   VM      1057 non-null   float64
#  8   Y       1056 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 74.4 KB

# %%
data_2.isnull().sum() # Missing value in each column
# Out:
# T      0
# TM     0
# Tm     0
# SLP    0
# H      0
# VV     0
# V      0
# VM     0
# Y      1
# dtype: int64

# %%
# Check for null values
sns.heatmap(data_2.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
data_2=data_2.dropna() ## Drop missing value 
#sns.pairplot(df)

# %%
data_2.corr()
# Out:
#             T        TM        Tm       SLP         H        VV         V  \
# T    1.000000  0.967445  0.955438 -0.884042 -0.502982  0.636501  0.295755
# TM   0.967445  1.000000  0.894166 -0.825101 -0.580968  0.604266  0.286558
# Tm   0.955438  0.894166  1.000000 -0.919146 -0.286163  0.572180  0.288561
# SLP -0.884042 -0.825101 -0.919146  1.000000  0.241980 -0.515457 -0.325188
# H   -0.502982 -0.580968 -0.286163  0.241980  1.000000 -0.468398 -0.386648
# VV   0.636501  0.604266  0.572180 -0.515457 -0.468398  1.000000  0.372076
# V    0.295755  0.286558  0.288561 -0.325188 -0.386648  0.372076  1.000000
# VM   0.283749  0.292896  0.262685 -0.308298 -0.363104  0.340184  0.776653
# Y   -0.630047 -0.564417 -0.678593  0.633072  0.116002 -0.572740 -0.260186
#
#            VM         Y
# T    0.283749 -0.630047
# TM   0.292896 -0.564417
# Tm   0.262685 -0.678593
# SLP -0.308298  0.633072
# H   -0.363104  0.116002
# VV   0.340184 -0.572740
# V    0.776653 -0.260186
# VM   1.000000 -0.216642
# ...

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = data_2.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data_2[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
sns.distplot(data_2['Y']) # distribution of response
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9440\431919805.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['Y']) # distribution of response
# <Axes: xlabel='Y', ylabel='Density'>

# %%
X=data_2.iloc[:,:-1] ## independent features
y=data_2.iloc[:,-1] ## dependent features

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-1.15715489e+00, -2.59671658e-01, -4.27344586e+00,  3.25604452e-01,
#        -1.40228895e+00, -4.16513743e+01, -1.31958205e+00, -1.54629497e-02])

# %%
regressor.intercept_
# Out:
# 84.94521150076456

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.550455397932239

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.5380287625183339

# %%
prediction=regressor.predict(X_test)
sns.distplot(y_test-prediction)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_9440\3657403504.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)
# <Axes: xlabel='Y', ylabel='Density'>

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 38.417390297428774
# MSE: 2887.256950028138
# RMSE: 53.733201561307865

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree=DecisionTreeRegressor(criterion="squared_error")

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(dtree.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 1.0

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(dtree.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.6847564476674015

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(dtree,X,y,cv=5)
score.mean()
# Out:
# 0.6157876948344896

# %%
prediction = dtree.predict(X_train)

# %%
#print('MAE:', metrics.mean_absolute_error(y_test, prediction))
#print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, prediction)))
# Out:
# RMSE: 2.790782497761797e-15

# %%
X_train.columns
# Out:
# Index(['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM'], dtype='object')

# %%
from sklearn import tree 
tree.plot_tree(dtree,feature_names=['T', 'TM', 'Tm', 'SLP', 'H', 'VV', 'V', 'VM'])
# Out:
# [Text(0.48817065706635854, 0.9772727272727273, 'T <= 24.25\nsquared_error = 6940.294\nsamples = 739\nvalue = 112.22'),
#  Text(0.18152984565881328, 0.9318181818181818, 'VV <= 1.2\nsquared_error = 6399.581\nsamples = 297\nvalue = 181.724'),
#  Text(0.047543084642233856, 0.8863636363636364, 'V <= 0.8\nsquared_error = 4366.69\nsamples = 120\nvalue = 225.606'),
#  Text(0.013089005235602094, 0.8409090909090909, 'SLP <= 1016.95\nsquared_error = 4358.309\nsamples = 10\nvalue = 305.078'),
#  Text(0.006980802792321117, 0.7954545454545454, 'TM <= 23.75\nsquared_error = 1597.08\nsamples = 5\nvalue = 245.74'),
#  Text(0.0034904013961605585, 0.75, 'VV <= 0.65\nsquared_error = 33.11\nsamples = 2\nvalue = 282.662'),
#  Text(0.0017452006980802793, 0.7045454545454546, 'squared_error = 0.0\nsamples = 1\nvalue = 288.417'),
#  Text(0.005235602094240838, 0.7045454545454546, 'squared_error = -0.0\nsamples = 1\nvalue = 276.908'),
# ...

# %% [markdown]
# # max depth

# %% [markdown]
# #The first parameter to tune is max_depth. This indicates how deep the tree can be. The deeper the tree, the more splits it has and it captures more information about the data. We fit a decision tree with depths ranging from 1 to 32 and plot the training and test auc scores.

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True).astype(int)
train_results = []
test_results = []
for max_depth in max_depths:
    dt = DecisionTreeRegressor(max_depth=max_depth)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
    train_results.append(rmse)
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    test_results.append(rmse1)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label="Train RMSE")
line2, = plt.plot(max_depths, test_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Tree depth')
plt.show()

# %%
DecisionTreeRegressor(max_depth=max_depth)
# Out:
# DecisionTreeRegressor(max_depth=32)

# %% [markdown]
# #Add R  Square value

# %%
from sklearn.metrics import r2_score

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True).astype(int)
train_results = []
test_results = []
train_r2_results = []
test_r2_results = []

for max_depth in max_depths:
    dt = DecisionTreeRegressor(max_depth=max_depth)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
    train_r2 = r2_score(y_train, train_pred)
    train_results.append(rmse)
    train_r2_results.append(train_r2)
    
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    test_r2 = r2_score(y_test, y_pred)
    test_results.append(rmse1)
    test_r2_results.append(test_r2)

from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label="Train RMSE")
line2, = plt.plot(max_depths, test_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Tree depth')
plt.show()

plt.figure()
line3, = plt.plot(max_depths, train_r2_results, 'b', label="Train R-squared")
line4, = plt.plot(max_depths, test_r2_results, 'r', label="Test R-squared")
plt.legend(handler_map={line3: HandlerLine2D(numpoints=2)})
plt.ylabel('R-squared score')
plt.xlabel('Tree depth')
plt.show()

# %% [markdown]
# # min_samples_split
# min_samples_split represents the minimum number of samples required to split an internal node. This can vary between considering at least one sample at each node to considering all of the samples at each node. When we increase this parameter, the tree becomes more constrained as it has to consider more samples at each node. Here we will vary the parameter from 10% to 100% of the samples

# %%
min_samples_splits = np.linspace(0.1, 1.0, 10, endpoint=True)
train_results = []
test_results = []
train_r2_results = []
test_r2_results = []
for min_samples_split1 in min_samples_splits:
    dt = DecisionTreeRegressor(min_samples_split=min_samples_split1)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
    train_r2 = r2_score(y_train, train_pred)
    train_results.append(rmse)
    train_r2_results.append(train_r2)
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    test_r2 = r2_score(y_test, y_pred)
    test_results.append(rmse1)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(min_samples_splits, train_results, 'b', label="Train RMSE")
line2, = plt.plot(min_samples_splits, test_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Tree min ')
plt.show()

# %% [markdown]
# # Add R square

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True).astype(int)
train_rmse_results = []
test_rmse_results = []
train_r2_results = []
test_r2_results = []

for max_depth in max_depths:
    # Create and train the decision tree regressor
    dt = DecisionTreeRegressor(max_depth=max_depth)
    dt.fit(X_train, y_train)
    
    # Predictions on training data
    train_pred = dt.predict(X_train)
    train_rmse = np.sqrt(metrics.mean_squared_error(y_train, train_pred))
    train_r2 = r2_score(y_train, train_pred)
    
    train_rmse_results.append(train_rmse)
    train_r2_results.append(train_r2)
    
    # Predictions on test data
    y_pred = dt.predict(X_test)
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    test_r2 = r2_score(y_test, y_pred)
    
    test_rmse_results.append(test_rmse)
    test_r2_results.append(test_r2)

# Debugging print statement to check lengths
print(f"Length of max_depths: {len(max_depths)}")
print(f"Length of train_r2_results: {len(train_r2_results)}")
print(f"Length of test_r2_results: {len(test_r2_results)}")

# Plotting RMSE
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_rmse_results, 'b', label="Train RMSE")
line2, = plt.plot(max_depths, test_rmse_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Tree depth')
plt.show()

# Plotting R-squared
plt.figure()
line3, = plt.plot(max_depths, train_r2_results, 'b', label="Train R-squared")
line4, = plt.plot(max_depths, test_r2_results, 'r', label="Test R-squared")
plt.legend(handler_map={line3: HandlerLine2D(numpoints=2)})
plt.ylabel('R-squared score')
plt.xlabel('Tree depth')
plt.show()
# Out:
# Length of max_depths: 32
# Length of train_r2_results: 32
# Length of test_r2_results: 32

# %% [markdown]
# ## Min Sample Leafs

# %%
min_samples_leafs = np.linspace(0.1, 0.5, 5, endpoint=True)
train_results = []
test_results = []
for min_samples_split1 in min_samples_leafs:
    dt = DecisionTreeRegressor(min_samples_leaf=min_samples_split1)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
    train_results.append(rmse)
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    test_results.append(rmse1)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(min_samples_leafs, train_results, 'b', label="Train RMSE")
line2, = plt.plot(min_samples_leafs, test_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Tree min ')
plt.show()

# %% [markdown]
# # Add R^2

# %%
from sklearn.metrics import r2_score

min_samples_leafs = np.linspace(0.1, 0.5, 5, endpoint=True)
train_rmse_results = []
test_rmse_results = []
train_r2_results = []
test_r2_results = []

for min_samples_split1 in min_samples_leafs:
    dt = DecisionTreeRegressor(min_samples_leaf=min_samples_split1)
    dt.fit(X_train, y_train)
    
    # RMSE for training data
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train, train_pred))
    train_rmse_results.append(rmse)
    
    # R-squared for training data
    train_r2 = r2_score(y_train, train_pred)
    train_r2_results.append(train_r2)
    
    # RMSE for test data
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    test_rmse_results.append(rmse1)
    
    # R-squared for test data
    test_r2 = r2_score(y_test, y_pred)
    test_r2_results.append(test_r2)

# Plotting RMSE
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(min_samples_leafs, train_rmse_results, 'b', label="Train RMSE")
line2, = plt.plot(min_samples_leafs, test_rmse_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Min samples leaf')
plt.show()

# Plotting R-squared
plt.figure()
line3, = plt.plot(min_samples_leafs, train_r2_results, 'b', label="Train R-squared")
line4, = plt.plot(min_samples_leafs, test_r2_results, 'r', label="Test R-squared")
plt.legend(handler_map={line3: HandlerLine2D(numpoints=2)})
plt.ylabel('R-squared score')
plt.xlabel('Min samples leaf')
plt.show()

# %% [markdown]
# ## Max leaf Node

# %%
max_leaf_node = [None,10,20,30,40,50,60,70]
train_results = []
test_results = []
for mf in max_leaf_node:
    dt = DecisionTreeRegressor(max_leaf_nodes = mf)
    dt.fit(X_train, y_train)
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
    train_results.append(rmse)
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    test_results.append(rmse1)
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_leaf_node, train_results, 'b', label="Train RMSE")
line2, = plt.plot(max_leaf_node, test_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Tree min ')
plt.show()

# %% [markdown]
# #Add R^2

# %%
from sklearn.metrics import r2_score

max_leaf_node = [None, 10, 20, 30, 40, 50, 60, 70]
train_rmse_results = []
test_rmse_results = []
train_r2_results = []
test_r2_results = []

for mf in max_leaf_node:
    dt = DecisionTreeRegressor(max_leaf_nodes=mf)
    dt.fit(X_train, y_train)
    
    # RMSE for training data
    train_pred = dt.predict(X_train)
    rmse = np.sqrt(metrics.mean_squared_error(y_train, train_pred))
    train_rmse_results.append(rmse)
    
    # R-squared for training data
    train_r2 = r2_score(y_train, train_pred)
    train_r2_results.append(train_r2)
    
    # RMSE for test data
    y_pred = dt.predict(X_test)
    rmse1 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    test_rmse_results.append(rmse1)
    
    # R-squared for test data
    test_r2 = r2_score(y_test, y_pred)
    test_r2_results.append(test_r2)

# Plotting RMSE
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_leaf_node, train_rmse_results, 'b', label="Train RMSE")
line2, = plt.plot(max_leaf_node, test_rmse_results, 'r', label="Test RMSE")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('RMSE score')
plt.xlabel('Max Leaf Nodes')
plt.show()

# Plotting R-squared
plt.figure()
line3, = plt.plot(max_leaf_node, train_r2_results, 'b', label="Train R-squared")
line4, = plt.plot(max_leaf_node, test_r2_results, 'r', label="Test R-squared")
plt.legend(handler_map={line3: HandlerLine2D(numpoints=2)})
plt.ylabel('R-squared score')
plt.xlabel('Max Leaf Nodes')
plt.show()

# %%
max_depth=6
min_samples_split = 0.4
min_samples_leafs = 0.2
max_leaf_node = 30 

dt = DecisionTreeRegressor(max_depth = 6,min_samples_split = 0.4,min_samples_leaf = 0.2,max_leaf_nodes=30)
dt.fit(X_train, y_train)
train_pred = dt.predict(X_train)
rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
print(rmse)
y_pred = dt.predict(X_test)
rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print(rmse1)
# Out:
# 58.714519903876344
# 62.28085809224046

# %%
from sklearn.metrics import r2_score

# Define the decision tree regressor with specified parameters
dt = DecisionTreeRegressor(max_depth=6, min_samples_split=0.4, min_samples_leaf=0.2, max_leaf_nodes=30)

# Fit the model on the training data
dt.fit(X_train, y_train)

# Predict on the training data
train_pred = dt.predict(X_train)

# Calculate RMSE for the training data
rmse_train = np.sqrt(metrics.mean_squared_error(y_train, train_pred))
print(f"Training RMSE: {rmse_train}")

# Calculate R-squared for the training data
r2_train = r2_score(y_train, train_pred)
print(f"Training R-squared: {r2_train}")

# Predict on the test data
y_pred = dt.predict(X_test)

# Calculate RMSE for the test data
rmse_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print(f"Test RMSE: {rmse_test}")

# Calculate R-squared for the test data
r2_test = r2_score(y_test, y_pred)
print(f"Test R-squared: {r2_test}")
# Out:
# Training RMSE: 58.71451990387633
# Training R-squared: 0.5032782541828968
# Test RMSE: 62.28085809224046
# Test R-squared: 0.44384952564782365

# %%
## Hyper Parameter Optimization
params={
 "splitter"    : ["best","random"] ,
 "max_depth"        : [  4, 5, 6, ],
 "min_samples_leaf" : [ 0.15,0.2,0.25],
  "min_samples_split": [0.35,0.4,0.45],
 "max_leaf_nodes":[25,30,35]
}

# %%
## Hyperparameter optimization using GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_root_mean_squared_error',n_jobs=-1,cv=10,verbose=3)

# %%
random_search.fit(X,y)
# Out:
# Fitting 10 folds for each of 162 candidates, totalling 1620 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [4, 5, 6], 'max_leaf_nodes': [25, 30, 35],
#                          'min_samples_leaf': [0.15, 0.2, 0.25],
#                          'min_samples_split': [0.35, 0.4, 0.45],
#                          'splitter': ['best', 'random']},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
random_search.best_params_
# Out:
# {'max_depth': 4,
#  'max_leaf_nodes': 25,
#  'min_samples_leaf': 0.15,
#  'min_samples_split': 0.35,
#  'splitter': 'best'}

# %%
random_search.best_score_
# Out:
# -55.21387122156026

# %%
predictions=random_search.predict(X_test)

# %%
train_pred = random_search.predict(X_train)
rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
print(rmse)
y_pred = random_search.predict(X_test)
rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print(rmse1)
# Out:
# 54.26071134815856
# 56.229095361743006

# %%
dt = DecisionTreeRegressor(max_depth=4,max_leaf_nodes=35,min_samples_leaf=0.15,min_samples_split=0.35,splitter='best')
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, max_leaf_nodes=35, min_samples_leaf=0.15,
#                       min_samples_split=0.35)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(24,14))
tree.plot_tree(dt,filled=True,fontsize=14)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= 24.25\nsquared_error = 6940.294\nsamples = 739\nvalue = 112.22'),
#  Text(0.25, 0.5, 'x[5] <= 1.2\nsquared_error = 6399.581\nsamples = 297\nvalue = 181.724'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 4366.69\nsamples = 120\nvalue = 225.606'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 5587.263\nsamples = 177\nvalue = 151.974'),
#  Text(0.75, 0.5, 'x[4] <= 62.5\nsquared_error = 1876.365\nsamples = 442\nvalue = 65.517'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 2187.875\nsamples = 242\nvalue = 78.047'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 1079.563\nsamples = 200\nvalue = 50.355')]

# %% [markdown]
# # some chenges

# %%
## Hyper Parameter Optimization
params={
 "splitter"    : ["best","random"] ,
 "max_depth"        : [  1, 3, 4, ],
 "min_samples_leaf" : [ 0.11,0.13,0.15],
  "min_samples_split": [0.20,0.25,0.30],
 "max_leaf_nodes":[15,20,25]
}

# %%
## Hyperparameter optimization using GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_root_mean_squared_error',n_jobs=-1,cv=10,verbose=3)
random_search.fit(X,y)
# Out:
# Fitting 10 folds for each of 162 candidates, totalling 1620 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [1, 3, 4], 'max_leaf_nodes': [15, 20, 25],
#                          'min_samples_leaf': [0.11, 0.13, 0.15],
#                          'min_samples_split': [0.2, 0.25, 0.3],
#                          'splitter': ['best', 'random']},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
random_search.best_params_
# Out:
# {'max_depth': 4,
#  'max_leaf_nodes': 15,
#  'min_samples_leaf': 0.11,
#  'min_samples_split': 0.2,
#  'splitter': 'best'}

# %%
random_search.best_score_
predictions=random_search.predict(X_test)
train_pred = random_search.predict(X_train)
rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
print(rmse)
y_pred = random_search.predict(X_test)
rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print(rmse1)
# Out:
# 52.23327272354688
# 54.41511482814815

# %%
dt = DecisionTreeRegressor(max_depth=4,max_leaf_nodes=15,min_samples_leaf=0.11,min_samples_split=0.2,splitter='best')
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, max_leaf_nodes=15, min_samples_leaf=0.11,
#                       min_samples_split=0.2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(24,14))
tree.plot_tree(dt,filled=True,fontsize=14)
# Out:
# [Text(0.4230769230769231, 0.875, 'x[0] <= 24.25\nsquared_error = 6940.294\nsamples = 739\nvalue = 112.22'),
#  Text(0.15384615384615385, 0.625, 'x[5] <= 1.2\nsquared_error = 6399.581\nsamples = 297\nvalue = 181.724'),
#  Text(0.07692307692307693, 0.375, 'squared_error = 4366.69\nsamples = 120\nvalue = 225.606'),
#  Text(0.23076923076923078, 0.375, 'x[2] <= 11.3\nsquared_error = 5587.263\nsamples = 177\nvalue = 151.974'),
#  Text(0.15384615384615385, 0.125, 'squared_error = 5914.907\nsamples = 88\nvalue = 179.174'),
#  Text(0.3076923076923077, 0.125, 'squared_error = 3808.463\nsamples = 89\nvalue = 125.08'),
#  Text(0.6923076923076923, 0.625, 'x[4] <= 62.5\nsquared_error = 1876.365\nsamples = 442\nvalue = 65.517'),
#  Text(0.5384615384615384, 0.375, 'x[4] <= 44.5\nsquared_error = 2187.875\nsamples = 242\nvalue = 78.047'),
#  Text(0.46153846153846156, 0.125, 'squared_error = 1324.308\nsamples = 94\nvalue = 87.992'),
# ...

# %% [markdown]
# #another changes

# %%
## Hyper Parameter Optimization
params={
 "splitter"    : ["best","random"] ,
 "max_depth"        : [5,6,7 ],
 "min_samples_leaf" : [ 0.12,0.14,0.17],
  "min_samples_split": [0.10,0.15,0.20],
 "max_leaf_nodes":[5,10,15]
}

# %%
## Hyperparameter optimization using GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
random_search=GridSearchCV(dtree,param_grid=params,scoring='neg_root_mean_squared_error',n_jobs=-1,cv=10,verbose=3)
random_search.fit(X,y)
# Out:
# Fitting 10 folds for each of 162 candidates, totalling 1620 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [5, 6, 7], 'max_leaf_nodes': [5, 10, 15],
#                          'min_samples_leaf': [0.12, 0.14, 0.17],
#                          'min_samples_split': [0.1, 0.15, 0.2],
#                          'splitter': ['best', 'random']},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
random_search.best_params_
# Out:
# {'max_depth': 5,
#  'max_leaf_nodes': 10,
#  'min_samples_leaf': 0.12,
#  'min_samples_split': 0.1,
#  'splitter': 'best'}

# %%
random_search.best_score_
predictions=random_search.predict(X_test)
train_pred = random_search.predict(X_train)
rmse = np.sqrt(metrics.mean_squared_error(y_train,train_pred))
print(rmse)
y_pred = random_search.predict(X_test)
rmse1 = np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print(rmse1)
# Out:
# 53.88022673921027
# 56.23500166463116

# %%
dt = DecisionTreeRegressor(max_depth=5,max_leaf_nodes=10,min_samples_leaf=0.12,min_samples_split=0.1,splitter='best')
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, max_leaf_nodes=10, min_samples_leaf=0.12,
#                       min_samples_split=0.1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(24,14))
tree.plot_tree(dt,filled=True,fontsize=14)
# Out:
# [Text(0.4090909090909091, 0.875, 'x[0] <= 24.25\nsquared_error = 6940.294\nsamples = 739\nvalue = 112.22'),
#  Text(0.18181818181818182, 0.625, 'x[5] <= 1.2\nsquared_error = 6399.581\nsamples = 297\nvalue = 181.724'),
#  Text(0.09090909090909091, 0.375, 'squared_error = 4366.69\nsamples = 120\nvalue = 225.606'),
#  Text(0.2727272727272727, 0.375, 'squared_error = 5587.263\nsamples = 177\nvalue = 151.974'),
#  Text(0.6363636363636364, 0.625, 'x[4] <= 62.5\nsquared_error = 1876.365\nsamples = 442\nvalue = 65.517'),
#  Text(0.45454545454545453, 0.375, 'x[4] <= 44.5\nsquared_error = 2187.875\nsamples = 242\nvalue = 78.047'),
#  Text(0.36363636363636365, 0.125, 'squared_error = 1324.308\nsamples = 94\nvalue = 87.992'),
#  Text(0.5454545454545454, 0.125, 'squared_error = 2633.655\nsamples = 148\nvalue = 71.731'),
#  Text(0.8181818181818182, 0.375, 'x[5] <= 2.0\nsquared_error = 1079.563\nsamples = 200\nvalue = 50.355'),
# ...

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Initialize the RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100, max_depth=None, random_state=42)

# Fit the model on the training data
rf.fit(X_train, y_train)

# Predict on the training data
train_pred = rf.predict(X_train)

# Calculate RMSE for the training data
rmse_train = np.sqrt(mean_squared_error(y_train, train_pred))
print(f"Training RMSE: {rmse_train}")

# Calculate R-squared for the training data
r2_train = r2_score(y_train, train_pred)
print(f"Training R-squared: {r2_train}")

# Predict on the test data
y_pred = rf.predict(X_test)

# Calculate RMSE for the test data
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Test RMSE: {rmse_test}")

# Calculate R-squared for the test data
r2_test = r2_score(y_test, y_pred)
print(f"Test R-squared: {r2_test}")
# Out:
# Training RMSE: 12.825922944085052
# Training R-squared: 0.9762972138701946
# Test RMSE: 38.54141223730032
# Test R-squared: 0.7870202146527351
