# %%
import pandas as pd
from scipy.stats import f_oneway
from statsmodels.formula.api import ols

# %%
data=pd.read_csv(r"C:\Users\USER\Downloads\Iris (2).csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_lm_one_categorical=ols('SepalLengthCm ~ C(Species)', data=data).fit()
sm.stats.anova_lm(iris_lm_one_categorical, typ=2)
# Out:
#                sum_sq     df           F        PR(>F)
# C(Species)  63.212133    2.0  119.264502  1.669669e-31
# Residual    38.956200  147.0         NaN           NaN

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.datasets import load_iris
X = data[ 'SepalLengthCm']
y = data['Species']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 7
#       5 y = data['Species']
#       6 X = sm.add_constant(X)
# ----> 7 model = sm.OLS(y, X).fit()
#       8 print(model.summary())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\regression\linear_model.py:923, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     920     msg = ("Weights are not supported in OLS and will be ignored"
#     921            "An exception will be raised in the next version.")
#     922     warnings.warn(msg, ValueWarning)
# --> 923 super(OLS, self).__init__(endog, exog, missing=missing,
#     924                           hasconst=hasconst, **kwargs)
#     925 if "weights" in self._init_keys:
#     926     self._init_keys.remove("weights")
#
# ...

# %%
up=pd.

# %%
# Example data:
# df = pd.DataFrame({'success': [50, 30, 20], 'total': [100, 100, 100]})

# Extract the success and total counts
successes = df['success']
trials = df['total']

# Perform the Z-test for proportions
# The alternative hypothesis can be 'two-sided', 'smaller', or 'larger'
# For a two-sided test, we use alternative='two-sided'
stat, p_value = proportions_ztest(successes, trials, alternative='two-sided')

# Output the results
print(f"Z-statistic: {stat}")
print(f"P-value: {p_value}")

# Check if the result is statistically significant (common significance level is 0.05)
if p_value < 0.05:
    print("The difference is statistically significant.")
else:
    print("The difference is not statistically significant.")
Mak

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\USER\Documents\Iris data set .csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
  
# creating dummies for gender 
data['Gender'] = data['Gender'].map({'Male':0, 'Female':1}) 
  
# the independent variables set 
X = data[['Gender', 'Height', 'Weight']] 
  
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
